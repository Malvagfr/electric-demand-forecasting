# %% [markdown]
# https://datosclima.es/Aemet2013/DescargaDatos.html

# %%
import pandas as pd

# %%
pd.read_excel('../data/Temperature/Aemet2015-01/Aemet2015-01-01.xls')
# Out:
#                                                 España Unnamed: 1  \
# 0    Actualizado: viernes, 02 enero 2015 a las 09:0...        NaN
# 1                         Fecha: jueves, 01 enero 2015        NaN
# 2                                                  NaN        NaN
# 3                                             Estación  Provincia
# 4                                      Estaca de Bares   A Coruña
# ..                                                 ...        ...
# 773                                           Leciñena   Zaragoza
# 774                                          Valmadrid   Zaragoza
# 775                                             Quinto   Zaragoza
# 776                                              Caspe   Zaragoza
# 777                                          Bujaraloz   Zaragoza
#
#                   Unnamed: 2               Unnamed: 3              Unnamed: 4  \
# 0                        NaN                      NaN                     NaN
# ...
